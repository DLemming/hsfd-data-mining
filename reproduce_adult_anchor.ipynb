# %% [markdown]
# # Reproduce ANCHOR results from the paper

# %% [markdown]
# ### 1. Init

# %%
from anchor import anchor_tabular
import numpy as np
import pickle
import pandas as pd

np.random.seed(1)

# %% [markdown]
# ### 2. Load Train/Test Sets

# %%
name = 'adult'

# Load train set
title = "scripts/datasets/train_set_"+name+"_strat.p"
train = open(title,"rb")
train_set: pd.DataFrame = pickle.load(train)

title = "scripts/datasets/train_label_"+name+"_strat.p"
train_l = open(title,"rb")
train_label: pd.DataFrame = pickle.load(train_l)

# Load Test set
title = "scripts/datasets/test_set_" + name + "_strat.p"
test = open(title, "rb")
test_set: pd.DataFrame = pickle.load(test)

title = "scripts/datasets/test_label_" + name + "_strat.p"
test_l = open(title, "rb")
test_label: pd.DataFrame = pickle.load(test_l)

# Reset indices
train_set = train_set.reset_index(drop=True)
train_label = train_label.reset_index(drop=True)
test_set = test_set.reset_index(drop=True)
test_label = test_label.reset_index(drop=True)

# Convert object columns to int
train_set = train_set.astype(int)
test_set = test_set.astype(int)

print("Length train set:", len(train_set))
print("Length test set:", len(test_set))
# Out:
# Length train set: 21113
# Length test set: 9049

# %% [markdown]
# ### 3a. Fit models

# %%
### Fit xgboost, lightgbm and catboost ###
### The models provided with the repo don't match the paper's own prepared dataset

from xgboost import XGBClassifier
xgb = XGBClassifier(
    C= 1,
    penalty='l2',
    objective='binary:logistic',
    seed = 42,
    bootstrap=True,
    max_depth=90,
    learning_rate=0.1,
    n_estimators=500,
    tree_method='auto'
)
xgb.fit(train_set.values, train_label.values)

from sklearn.linear_model import LogisticRegression
lg = LogisticRegression(
    penalty='l2',
    C=1.0,
    solver='lbfgs',     # or 'liblinear' (both support L2)
    max_iter=1000,
    random_state=42
)
lg.fit(train_set.values, train_label.values)

from catboost import CatBoostClassifier
cat = CatBoostClassifier(
    iterations=500,         # Equivalent to n_estimators
    depth=10,               # Equivalent to max_depth
    learning_rate=0.1,      # Same learning rate
    loss_function='Logloss',  # For binary classification
    bootstrap_type='Bayesian',  # Equivalent to bootstrap in XGBoost
    random_seed=42,
    od_type='Iter',         # Early stopping after 'iterations'
    od_wait=50              # How many iterations to wait for improvement
)
cat.fit(train_set.values, train_label.values)
# Out:
# [20:30:08] WARNING: ../src/learner.cc:516:
# Parameters: { C, bootstrap, penalty } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 0:	learn: 0.6058914	total: 73.6ms	remaining: 36.7s
# 1:	learn: 0.5310385	total: 90.9ms	remaining: 22.6s
# 2:	learn: 0.4791864	total: 97.3ms	remaining: 16.1s
# 3:	learn: 0.4388315	total: 110ms	remaining: 13.7s
# 4:	learn: 0.4083986	total: 125ms	remaining: 12.4s
# 5:	learn: 0.3848253	total: 138ms	remaining: 11.4s
# 6:	learn: 0.3676019	total: 150ms	remaining: 10.5s
# 7:	learn: 0.3561208	total: 155ms	remaining: 9.55s
# 8:	learn: 0.3459560	total: 168ms	remaining: 9.17s
# 9:	learn: 0.3372917	total: 181ms	remaining: 8.87s
# 10:	learn: 0.3312674	total: 194ms	remaining: 8.62s
# 11:	learn: 0.3257599	total: 206ms	remaining: 8.39s
# 12:	learn: 0.3224239	total: 218ms	remaining: 8.17s
# 13:	learn: 0.3185056	total: 231ms	remaining: 8.03s
# 14:	learn: 0.3153705	total: 245ms	remaining: 7.92s
# 15:	learn: 0.3126248	total: 257ms	remaining: 7.78s
# 16:	learn: 0.3098336	total: 271ms	remaining: 7.69s
# 17:	learn: 0.3072989	total: 284ms	remaining: 7.61s
# 18:	learn: 0.3054159	total: 297ms	remaining: 7.53s
# 19:	learn: 0.3033854	total: 312ms	remaining: 7.48s
# 20:	learn: 0.3013124	total: 324ms	remaining: 7.39s
# 21:	learn: 0.2996400	total: 337ms	remaining: 7.32s
# 22:	learn: 0.2981234	total: 350ms	remaining: 7.25s
# 23:	learn: 0.2960304	total: 361ms	remaining: 7.17s
# 24:	learn: 0.2946966	total: 374ms	remaining: 7.1s
# 25:	learn: 0.2933515	total: 386ms	remaining: 7.04s
# 26:	learn: 0.2926469	total: 399ms	remaining: 6.98s
# 27:	learn: 0.2914753	total: 412ms	remaining: 6.94s
# 28:	learn: 0.2903570	total: 425ms	remaining: 6.89s
# 29:	learn: 0.2889900	total: 437ms	remaining: 6.85s
# 30:	learn: 0.2874883	total: 450ms	remaining: 6.81s
# 31:	learn: 0.2867245	total: 463ms	remaining: 6.77s
# 32:	learn: 0.2859961	total: 475ms	remaining: 6.72s
# 33:	learn: 0.2850248	total: 487ms	remaining: 6.67s
# 34:	learn: 0.2841930	total: 499ms	remaining: 6.63s
# 35:	learn: 0.2833339	total: 513ms	remaining: 6.62s
# 36:	learn: 0.2819250	total: 527ms	remaining: 6.59s
# 37:	learn: 0.2805261	total: 540ms	remaining: 6.57s
# 38:	learn: 0.2794340	total: 554ms	remaining: 6.55s
# 39:	learn: 0.2784121	total: 566ms	remaining: 6.51s
# 40:	learn: 0.2775903	total: 579ms	remaining: 6.48s
# 41:	learn: 0.2764600	total: 592ms	remaining: 6.46s
# 42:	learn: 0.2754418	total: 605ms	remaining: 6.43s
# 43:	learn: 0.2747255	total: 618ms	remaining: 6.4s
# 44:	learn: 0.2740187	total: 630ms	remaining: 6.37s
# 45:	learn: 0.2725712	total: 643ms	remaining: 6.35s
# 46:	learn: 0.2717767	total: 655ms	remaining: 6.32s
# 47:	learn: 0.2709050	total: 669ms	remaining: 6.3s
# 48:	learn: 0.2697214	total: 682ms	remaining: 6.28s
# 49:	learn: 0.2690876	total: 695ms	remaining: 6.25s
# 50:	learn: 0.2684154	total: 707ms	remaining: 6.23s
# 51:	learn: 0.2678902	total: 720ms	remaining: 6.2s
# 52:	learn: 0.2673636	total: 732ms	remaining: 6.17s
# 53:	learn: 0.2667517	total: 745ms	remaining: 6.15s
# 54:	learn: 0.2660392	total: 757ms	remaining: 6.13s
# 55:	learn: 0.2654829	total: 769ms	remaining: 6.1s
# 56:	learn: 0.2643950	total: 782ms	remaining: 6.08s
# 57:	learn: 0.2638627	total: 794ms	remaining: 6.05s
# 58:	learn: 0.2634608	total: 806ms	remaining: 6.02s
# 59:	learn: 0.2629548	total: 818ms	remaining: 6s
# 60:	learn: 0.2623041	total: 832ms	remaining: 5.99s
# 61:	learn: 0.2614928	total: 844ms	remaining: 5.96s
# 62:	learn: 0.2610751	total: 857ms	remaining: 5.95s
# 63:	learn: 0.2605871	total: 870ms	remaining: 5.93s
# 64:	learn: 0.2600747	total: 882ms	remaining: 5.9s
# 65:	learn: 0.2591822	total: 895ms	remaining: 5.88s
# 66:	learn: 0.2586630	total: 908ms	remaining: 5.87s
# 67:	learn: 0.2581141	total: 921ms	remaining: 5.85s
# 68:	learn: 0.2577111	total: 934ms	remaining: 5.83s
# 69:	learn: 0.2565114	total: 948ms	remaining: 5.82s
# 70:	learn: 0.2557989	total: 961ms	remaining: 5.8s
# 71:	learn: 0.2553714	total: 973ms	remaining: 5.78s
# 72:	learn: 0.2547947	total: 985ms	remaining: 5.76s
# 73:	learn: 0.2543432	total: 999ms	remaining: 5.75s
# 74:	learn: 0.2534350	total: 1.01s	remaining: 5.73s
# 75:	learn: 0.2533617	total: 1.01s	remaining: 5.66s
# 76:	learn: 0.2522960	total: 1.03s	remaining: 5.64s
# 77:	learn: 0.2516912	total: 1.04s	remaining: 5.62s
# 78:	learn: 0.2508699	total: 1.05s	remaining: 5.61s
# 79:	learn: 0.2500730	total: 1.06s	remaining: 5.59s
# 80:	learn: 0.2493459	total: 1.08s	remaining: 5.58s
# 81:	learn: 0.2488402	total: 1.09s	remaining: 5.56s
# 82:	learn: 0.2482596	total: 1.1s	remaining: 5.55s
# 83:	learn: 0.2479631	total: 1.12s	remaining: 5.53s
# 84:	learn: 0.2475942	total: 1.13s	remaining: 5.52s
# 85:	learn: 0.2472258	total: 1.14s	remaining: 5.5s
# 86:	learn: 0.2468499	total: 1.16s	remaining: 5.49s
# 87:	learn: 0.2463650	total: 1.17s	remaining: 5.48s
# 88:	learn: 0.2460460	total: 1.18s	remaining: 5.46s
# 89:	learn: 0.2453553	total: 1.2s	remaining: 5.44s
# 90:	learn: 0.2449993	total: 1.21s	remaining: 5.42s
# 91:	learn: 0.2443013	total: 1.22s	remaining: 5.41s
# 92:	learn: 0.2437850	total: 1.23s	remaining: 5.39s
# 93:	learn: 0.2432711	total: 1.25s	remaining: 5.38s
# 94:	learn: 0.2424819	total: 1.26s	remaining: 5.36s
# 95:	learn: 0.2420816	total: 1.27s	remaining: 5.34s
# 96:	learn: 0.2415671	total: 1.28s	remaining: 5.33s
# 97:	learn: 0.2409481	total: 1.29s	remaining: 5.31s
# 98:	learn: 0.2400988	total: 1.31s	remaining: 5.3s
# 99:	learn: 0.2394747	total: 1.32s	remaining: 5.29s
# 100:	learn: 0.2390480	total: 1.33s	remaining: 5.28s
# 101:	learn: 0.2382207	total: 1.35s	remaining: 5.26s
# 102:	learn: 0.2373893	total: 1.36s	remaining: 5.25s
# 103:	learn: 0.2368285	total: 1.38s	remaining: 5.24s
# 104:	learn: 0.2359401	total: 1.39s	remaining: 5.22s
# 105:	learn: 0.2353544	total: 1.4s	remaining: 5.21s
# 106:	learn: 0.2349302	total: 1.41s	remaining: 5.19s
# 107:	learn: 0.2343758	total: 1.43s	remaining: 5.18s
# 108:	learn: 0.2340467	total: 1.44s	remaining: 5.16s
# 109:	learn: 0.2336461	total: 1.45s	remaining: 5.14s
# 110:	learn: 0.2326917	total: 1.46s	remaining: 5.13s
# 111:	learn: 0.2321567	total: 1.48s	remaining: 5.11s
# 112:	learn: 0.2317304	total: 1.49s	remaining: 5.1s
# 113:	learn: 0.2312438	total: 1.5s	remaining: 5.08s
# 114:	learn: 0.2307043	total: 1.51s	remaining: 5.07s
# 115:	learn: 0.2301285	total: 1.53s	remaining: 5.06s
# 116:	learn: 0.2295826	total: 1.54s	remaining: 5.04s
# 117:	learn: 0.2293783	total: 1.55s	remaining: 5.03s
# 118:	learn: 0.2289160	total: 1.56s	remaining: 5.01s
# 119:	learn: 0.2283127	total: 1.58s	remaining: 5s
# 120:	learn: 0.2275448	total: 1.59s	remaining: 4.98s
# 121:	learn: 0.2271751	total: 1.6s	remaining: 4.97s
# 122:	learn: 0.2266279	total: 1.62s	remaining: 4.95s
# 123:	learn: 0.2262545	total: 1.63s	remaining: 4.94s
# 124:	learn: 0.2255798	total: 1.64s	remaining: 4.93s
# 125:	learn: 0.2249012	total: 1.66s	remaining: 4.91s
# 126:	learn: 0.2244049	total: 1.67s	remaining: 4.9s
# 127:	learn: 0.2240375	total: 1.68s	remaining: 4.89s
# 128:	learn: 0.2237459	total: 1.69s	remaining: 4.87s
# 129:	learn: 0.2228330	total: 1.71s	remaining: 4.86s
# 130:	learn: 0.2223238	total: 1.72s	remaining: 4.84s
# 131:	learn: 0.2219624	total: 1.73s	remaining: 4.83s
# 132:	learn: 0.2213835	total: 1.75s	remaining: 4.82s
# 133:	learn: 0.2206177	total: 1.76s	remaining: 4.8s
# 134:	learn: 0.2202779	total: 1.77s	remaining: 4.79s
# 135:	learn: 0.2196936	total: 1.78s	remaining: 4.78s
# 136:	learn: 0.2191772	total: 1.8s	remaining: 4.76s
# 137:	learn: 0.2186197	total: 1.81s	remaining: 4.75s
# 138:	learn: 0.2182713	total: 1.82s	remaining: 4.73s
# 139:	learn: 0.2176835	total: 1.84s	remaining: 4.72s
# 140:	learn: 0.2170799	total: 1.85s	remaining: 4.71s
# 141:	learn: 0.2163919	total: 1.86s	remaining: 4.69s
# 142:	learn: 0.2156518	total: 1.87s	remaining: 4.68s
# 143:	learn: 0.2152080	total: 1.89s	remaining: 4.67s
# 144:	learn: 0.2148373	total: 1.9s	remaining: 4.65s
# 145:	learn: 0.2144404	total: 1.91s	remaining: 4.63s
# 146:	learn: 0.2137691	total: 1.92s	remaining: 4.62s
# 147:	learn: 0.2133311	total: 1.94s	remaining: 4.61s
# 148:	learn: 0.2127916	total: 1.95s	remaining: 4.59s
# 149:	learn: 0.2121308	total: 1.96s	remaining: 4.58s
# 150:	learn: 0.2117102	total: 1.97s	remaining: 4.56s
# 151:	learn: 0.2111437	total: 1.99s	remaining: 4.55s
# 152:	learn: 0.2106821	total: 2s	remaining: 4.53s
# 153:	learn: 0.2101319	total: 2.01s	remaining: 4.52s
# 154:	learn: 0.2096810	total: 2.02s	remaining: 4.51s
# 155:	learn: 0.2089430	total: 2.04s	remaining: 4.49s
# 156:	learn: 0.2084899	total: 2.05s	remaining: 4.48s
# 157:	learn: 0.2077928	total: 2.06s	remaining: 4.47s
# 158:	learn: 0.2072502	total: 2.08s	remaining: 4.45s
# 159:	learn: 0.2066207	total: 2.09s	remaining: 4.44s
# 160:	learn: 0.2061527	total: 2.1s	remaining: 4.43s
# 161:	learn: 0.2056981	total: 2.12s	remaining: 4.41s
# 162:	learn: 0.2051701	total: 2.13s	remaining: 4.4s
# 163:	learn: 0.2047920	total: 2.14s	remaining: 4.39s
# 164:	learn: 0.2044263	total: 2.15s	remaining: 4.37s
# 165:	learn: 0.2038946	total: 2.17s	remaining: 4.36s
# 166:	learn: 0.2033610	total: 2.18s	remaining: 4.35s
# 167:	learn: 0.2029289	total: 2.19s	remaining: 4.33s
# 168:	learn: 0.2025632	total: 2.21s	remaining: 4.32s
# 169:	learn: 0.2021258	total: 2.22s	remaining: 4.3s
# 170:	learn: 0.2018315	total: 2.23s	remaining: 4.29s
# 171:	learn: 0.2013877	total: 2.24s	remaining: 4.28s
# 172:	learn: 0.2009269	total: 2.25s	remaining: 4.26s
# 173:	learn: 0.2005761	total: 2.27s	remaining: 4.25s
# 174:	learn: 0.2002296	total: 2.28s	remaining: 4.23s
# 175:	learn: 0.1997699	total: 2.29s	remaining: 4.22s
# 176:	learn: 0.1991775	total: 2.31s	remaining: 4.21s
# 177:	learn: 0.1989446	total: 2.32s	remaining: 4.19s
# 178:	learn: 0.1984850	total: 2.33s	remaining: 4.18s
# 179:	learn: 0.1980808	total: 2.34s	remaining: 4.17s
# 180:	learn: 0.1977372	total: 2.36s	remaining: 4.15s
# 181:	learn: 0.1973142	total: 2.37s	remaining: 4.14s
# 182:	learn: 0.1971552	total: 2.38s	remaining: 4.12s
# 183:	learn: 0.1966908	total: 2.39s	remaining: 4.11s
# 184:	learn: 0.1962343	total: 2.41s	remaining: 4.1s
# 185:	learn: 0.1958646	total: 2.42s	remaining: 4.08s
# 186:	learn: 0.1954587	total: 2.43s	remaining: 4.07s
# 187:	learn: 0.1952381	total: 2.44s	remaining: 4.06s
# 188:	learn: 0.1950113	total: 2.46s	remaining: 4.04s
# 189:	learn: 0.1944655	total: 2.47s	remaining: 4.03s
# 190:	learn: 0.1940163	total: 2.48s	remaining: 4.01s
# 191:	learn: 0.1936059	total: 2.49s	remaining: 4s
# 192:	learn: 0.1932421	total: 2.51s	remaining: 3.99s
# 193:	learn: 0.1929583	total: 2.52s	remaining: 3.97s
# 194:	learn: 0.1925541	total: 2.53s	remaining: 3.96s
# 195:	learn: 0.1922174	total: 2.54s	remaining: 3.95s
# 196:	learn: 0.1918656	total: 2.56s	remaining: 3.93s
# 197:	learn: 0.1913855	total: 2.57s	remaining: 3.92s
# 198:	learn: 0.1911087	total: 2.58s	remaining: 3.91s
# 199:	learn: 0.1906977	total: 2.6s	remaining: 3.89s
# 200:	learn: 0.1903824	total: 2.61s	remaining: 3.88s
# 201:	learn: 0.1899784	total: 2.62s	remaining: 3.87s
# 202:	learn: 0.1896332	total: 2.63s	remaining: 3.85s
# 203:	learn: 0.1892797	total: 2.65s	remaining: 3.84s
# 204:	learn: 0.1887437	total: 2.66s	remaining: 3.83s
# 205:	learn: 0.1882993	total: 2.67s	remaining: 3.81s
# 206:	learn: 0.1880348	total: 2.68s	remaining: 3.8s
# 207:	learn: 0.1877501	total: 2.7s	remaining: 3.78s
# 208:	learn: 0.1873549	total: 2.71s	remaining: 3.77s
# 209:	learn: 0.1870832	total: 2.72s	remaining: 3.76s
# 210:	learn: 0.1866927	total: 2.73s	remaining: 3.75s
# 211:	learn: 0.1864163	total: 2.75s	remaining: 3.73s
# 212:	learn: 0.1861410	total: 2.76s	remaining: 3.72s
# 213:	learn: 0.1856283	total: 2.77s	remaining: 3.71s
# 214:	learn: 0.1851710	total: 2.79s	remaining: 3.69s
# 215:	learn: 0.1849013	total: 2.8s	remaining: 3.68s
# 216:	learn: 0.1845484	total: 2.81s	remaining: 3.67s
# 217:	learn: 0.1841400	total: 2.82s	remaining: 3.65s
# 218:	learn: 0.1839506	total: 2.84s	remaining: 3.64s
# 219:	learn: 0.1834986	total: 2.85s	remaining: 3.63s
# 220:	learn: 0.1831946	total: 2.86s	remaining: 3.61s
# 221:	learn: 0.1827913	total: 2.88s	remaining: 3.6s
# 222:	learn: 0.1826251	total: 2.89s	remaining: 3.59s
# 223:	learn: 0.1822633	total: 2.9s	remaining: 3.57s
# 224:	learn: 0.1819389	total: 2.91s	remaining: 3.56s
# 225:	learn: 0.1815617	total: 2.92s	remaining: 3.55s
# 226:	learn: 0.1811840	total: 2.94s	remaining: 3.53s
# 227:	learn: 0.1809340	total: 2.95s	remaining: 3.52s
# 228:	learn: 0.1805513	total: 2.96s	remaining: 3.51s
# 229:	learn: 0.1801847	total: 2.98s	remaining: 3.49s
# 230:	learn: 0.1797641	total: 2.99s	remaining: 3.48s
# 231:	learn: 0.1794196	total: 3s	remaining: 3.47s
# 232:	learn: 0.1792077	total: 3.02s	remaining: 3.46s
# 233:	learn: 0.1790142	total: 3.04s	remaining: 3.46s
# 234:	learn: 0.1786597	total: 3.06s	remaining: 3.45s
# 235:	learn: 0.1783603	total: 3.07s	remaining: 3.44s
# 236:	learn: 0.1780637	total: 3.09s	remaining: 3.43s
# 237:	learn: 0.1778661	total: 3.1s	remaining: 3.42s
# 238:	learn: 0.1773770	total: 3.12s	remaining: 3.4s
# 239:	learn: 0.1768773	total: 3.13s	remaining: 3.39s
# 240:	learn: 0.1765745	total: 3.14s	remaining: 3.38s
# 241:	learn: 0.1762457	total: 3.16s	remaining: 3.37s
# 242:	learn: 0.1759710	total: 3.17s	remaining: 3.35s
# 243:	learn: 0.1755319	total: 3.18s	remaining: 3.34s
# 244:	learn: 0.1753328	total: 3.2s	remaining: 3.33s
# 245:	learn: 0.1749550	total: 3.21s	remaining: 3.31s
# 246:	learn: 0.1745972	total: 3.22s	remaining: 3.3s
# 247:	learn: 0.1742370	total: 3.23s	remaining: 3.29s
# 248:	learn: 0.1738912	total: 3.25s	remaining: 3.27s
# 249:	learn: 0.1736122	total: 3.26s	remaining: 3.26s
# 250:	learn: 0.1731028	total: 3.27s	remaining: 3.25s
# 251:	learn: 0.1729045	total: 3.29s	remaining: 3.23s
# 252:	learn: 0.1725009	total: 3.3s	remaining: 3.22s
# 253:	learn: 0.1723075	total: 3.31s	remaining: 3.21s
# 254:	learn: 0.1720521	total: 3.32s	remaining: 3.19s
# 255:	learn: 0.1717701	total: 3.33s	remaining: 3.18s
# 256:	learn: 0.1715764	total: 3.35s	remaining: 3.17s
# 257:	learn: 0.1713486	total: 3.36s	remaining: 3.15s
# 258:	learn: 0.1711787	total: 3.37s	remaining: 3.14s
# 259:	learn: 0.1707432	total: 3.39s	remaining: 3.13s
# 260:	learn: 0.1705004	total: 3.4s	remaining: 3.11s
# 261:	learn: 0.1703517	total: 3.41s	remaining: 3.1s
# 262:	learn: 0.1700904	total: 3.42s	remaining: 3.08s
# 263:	learn: 0.1697346	total: 3.44s	remaining: 3.07s
# 264:	learn: 0.1694493	total: 3.45s	remaining: 3.06s
# 265:	learn: 0.1690651	total: 3.46s	remaining: 3.04s
# 266:	learn: 0.1686932	total: 3.47s	remaining: 3.03s
# 267:	learn: 0.1682427	total: 3.49s	remaining: 3.02s
# 268:	learn: 0.1679073	total: 3.5s	remaining: 3.01s
# 269:	learn: 0.1676207	total: 3.51s	remaining: 2.99s
# 270:	learn: 0.1672097	total: 3.53s	remaining: 2.98s
# 271:	learn: 0.1668888	total: 3.54s	remaining: 2.97s
# 272:	learn: 0.1666573	total: 3.55s	remaining: 2.95s
# 273:	learn: 0.1662190	total: 3.56s	remaining: 2.94s
# 274:	learn: 0.1658563	total: 3.58s	remaining: 2.93s
# 275:	learn: 0.1656933	total: 3.59s	remaining: 2.91s
# 276:	learn: 0.1655360	total: 3.6s	remaining: 2.9s
# 277:	learn: 0.1651382	total: 3.62s	remaining: 2.89s
# 278:	learn: 0.1648442	total: 3.63s	remaining: 2.87s
# 279:	learn: 0.1644660	total: 3.64s	remaining: 2.86s
# 280:	learn: 0.1642205	total: 3.65s	remaining: 2.85s
# 281:	learn: 0.1638908	total: 3.67s	remaining: 2.83s
# 282:	learn: 0.1636310	total: 3.68s	remaining: 2.82s
# 283:	learn: 0.1634591	total: 3.69s	remaining: 2.81s
# 284:	learn: 0.1632455	total: 3.7s	remaining: 2.79s
# 285:	learn: 0.1629990	total: 3.71s	remaining: 2.78s
# 286:	learn: 0.1628596	total: 3.73s	remaining: 2.77s
# 287:	learn: 0.1624985	total: 3.74s	remaining: 2.75s
# 288:	learn: 0.1620693	total: 3.75s	remaining: 2.74s
# 289:	learn: 0.1616878	total: 3.77s	remaining: 2.73s
# 290:	learn: 0.1614665	total: 3.78s	remaining: 2.71s
# 291:	learn: 0.1612142	total: 3.79s	remaining: 2.7s
# 292:	learn: 0.1608422	total: 3.8s	remaining: 2.69s
# 293:	learn: 0.1603928	total: 3.81s	remaining: 2.67s
# 294:	learn: 0.1600367	total: 3.83s	remaining: 2.66s
# 295:	learn: 0.1598081	total: 3.84s	remaining: 2.65s
# 296:	learn: 0.1595099	total: 3.85s	remaining: 2.63s
# 297:	learn: 0.1592214	total: 3.87s	remaining: 2.62s
# 298:	learn: 0.1589851	total: 3.88s	remaining: 2.61s
# 299:	learn: 0.1586822	total: 3.89s	remaining: 2.59s
# 300:	learn: 0.1584601	total: 3.9s	remaining: 2.58s
# 301:	learn: 0.1581648	total: 3.92s	remaining: 2.57s
# 302:	learn: 0.1578659	total: 3.93s	remaining: 2.56s
# 303:	learn: 0.1574589	total: 3.94s	remaining: 2.54s
# 304:	learn: 0.1572036	total: 3.96s	remaining: 2.53s
# 305:	learn: 0.1569316	total: 3.97s	remaining: 2.52s
# 306:	learn: 0.1566380	total: 3.98s	remaining: 2.5s
# 307:	learn: 0.1564241	total: 3.99s	remaining: 2.49s
# 308:	learn: 0.1561951	total: 4.01s	remaining: 2.48s
# 309:	learn: 0.1558541	total: 4.02s	remaining: 2.46s
# 310:	learn: 0.1555746	total: 4.03s	remaining: 2.45s
# 311:	learn: 0.1553474	total: 4.04s	remaining: 2.44s
# 312:	learn: 0.1551757	total: 4.06s	remaining: 2.42s
# 313:	learn: 0.1549846	total: 4.07s	remaining: 2.41s
# 314:	learn: 0.1546689	total: 4.08s	remaining: 2.4s
# 315:	learn: 0.1545210	total: 4.09s	remaining: 2.38s
# 316:	learn: 0.1543202	total: 4.11s	remaining: 2.37s
# 317:	learn: 0.1540351	total: 4.12s	remaining: 2.36s
# 318:	learn: 0.1537725	total: 4.13s	remaining: 2.35s
# 319:	learn: 0.1536693	total: 4.15s	remaining: 2.33s
# 320:	learn: 0.1533540	total: 4.16s	remaining: 2.32s
# 321:	learn: 0.1529379	total: 4.18s	remaining: 2.31s
# 322:	learn: 0.1527110	total: 4.19s	remaining: 2.3s
# 323:	learn: 0.1525323	total: 4.2s	remaining: 2.28s
# 324:	learn: 0.1521386	total: 4.22s	remaining: 2.27s
# 325:	learn: 0.1519978	total: 4.23s	remaining: 2.26s
# 326:	learn: 0.1517386	total: 4.24s	remaining: 2.24s
# 327:	learn: 0.1514259	total: 4.25s	remaining: 2.23s
# 328:	learn: 0.1511630	total: 4.27s	remaining: 2.22s
# 329:	learn: 0.1508923	total: 4.28s	remaining: 2.21s
# 330:	learn: 0.1506829	total: 4.29s	remaining: 2.19s
# 331:	learn: 0.1504388	total: 4.3s	remaining: 2.18s
# 332:	learn: 0.1501990	total: 4.32s	remaining: 2.17s
# 333:	learn: 0.1498857	total: 4.33s	remaining: 2.15s
# 334:	learn: 0.1497020	total: 4.34s	remaining: 2.14s
# 335:	learn: 0.1495067	total: 4.36s	remaining: 2.13s
# 336:	learn: 0.1493881	total: 4.37s	remaining: 2.11s
# 337:	learn: 0.1492648	total: 4.38s	remaining: 2.1s
# 338:	learn: 0.1489071	total: 4.39s	remaining: 2.09s
# 339:	learn: 0.1487345	total: 4.41s	remaining: 2.07s
# 340:	learn: 0.1483758	total: 4.42s	remaining: 2.06s
# 341:	learn: 0.1480495	total: 4.43s	remaining: 2.05s
# 342:	learn: 0.1477681	total: 4.45s	remaining: 2.04s
# 343:	learn: 0.1474779	total: 4.46s	remaining: 2.02s
# 344:	learn: 0.1472561	total: 4.47s	remaining: 2.01s
# 345:	learn: 0.1471011	total: 4.48s	remaining: 2s
# 346:	learn: 0.1469785	total: 4.5s	remaining: 1.98s
# 347:	learn: 0.1466807	total: 4.51s	remaining: 1.97s
# 348:	learn: 0.1464484	total: 4.52s	remaining: 1.96s
# 349:	learn: 0.1462633	total: 4.53s	remaining: 1.94s
# 350:	learn: 0.1459849	total: 4.55s	remaining: 1.93s
# 351:	learn: 0.1457589	total: 4.56s	remaining: 1.92s
# 352:	learn: 0.1455505	total: 4.57s	remaining: 1.9s
# 353:	learn: 0.1451527	total: 4.58s	remaining: 1.89s
# 354:	learn: 0.1448619	total: 4.6s	remaining: 1.88s
# 355:	learn: 0.1446738	total: 4.61s	remaining: 1.86s
# 356:	learn: 0.1444366	total: 4.62s	remaining: 1.85s
# 357:	learn: 0.1441108	total: 4.63s	remaining: 1.84s
# 358:	learn: 0.1438611	total: 4.65s	remaining: 1.82s
# 359:	learn: 0.1435915	total: 4.66s	remaining: 1.81s
# 360:	learn: 0.1434127	total: 4.67s	remaining: 1.8s
# 361:	learn: 0.1432239	total: 4.69s	remaining: 1.79s
# 362:	learn: 0.1429677	total: 4.7s	remaining: 1.77s
# 363:	learn: 0.1427416	total: 4.71s	remaining: 1.76s
# 364:	learn: 0.1425738	total: 4.72s	remaining: 1.75s
# 365:	learn: 0.1423641	total: 4.74s	remaining: 1.73s
# 366:	learn: 0.1420656	total: 4.75s	remaining: 1.72s
# 367:	learn: 0.1418062	total: 4.76s	remaining: 1.71s
# 368:	learn: 0.1415889	total: 4.77s	remaining: 1.7s
# 369:	learn: 0.1414504	total: 4.79s	remaining: 1.68s
# 370:	learn: 0.1412080	total: 4.8s	remaining: 1.67s
# 371:	learn: 0.1409642	total: 4.82s	remaining: 1.66s
# 372:	learn: 0.1407393	total: 4.83s	remaining: 1.64s
# 373:	learn: 0.1404615	total: 4.84s	remaining: 1.63s
# 374:	learn: 0.1403324	total: 4.85s	remaining: 1.62s
# 375:	learn: 0.1401106	total: 4.86s	remaining: 1.6s
# 376:	learn: 0.1398814	total: 4.88s	remaining: 1.59s
# 377:	learn: 0.1396938	total: 4.89s	remaining: 1.58s
# 378:	learn: 0.1393467	total: 4.9s	remaining: 1.56s
# 379:	learn: 0.1390627	total: 4.91s	remaining: 1.55s
# 380:	learn: 0.1389368	total: 4.92s	remaining: 1.54s
# 381:	learn: 0.1387371	total: 4.94s	remaining: 1.52s
# 382:	learn: 0.1384839	total: 4.95s	remaining: 1.51s
# 383:	learn: 0.1383065	total: 4.96s	remaining: 1.5s
# 384:	learn: 0.1381523	total: 4.97s	remaining: 1.49s
# 385:	learn: 0.1379090	total: 4.99s	remaining: 1.47s
# 386:	learn: 0.1378047	total: 5s	remaining: 1.46s
# 387:	learn: 0.1375871	total: 5.02s	remaining: 1.45s
# 388:	learn: 0.1373486	total: 5.03s	remaining: 1.43s
# 389:	learn: 0.1370766	total: 5.04s	remaining: 1.42s
# 390:	learn: 0.1369041	total: 5.05s	remaining: 1.41s
# 391:	learn: 0.1367287	total: 5.07s	remaining: 1.4s
# 392:	learn: 0.1365084	total: 5.08s	remaining: 1.38s
# 393:	learn: 0.1363526	total: 5.09s	remaining: 1.37s
# 394:	learn: 0.1361136	total: 5.1s	remaining: 1.36s
# 395:	learn: 0.1358531	total: 5.12s	remaining: 1.34s
# 396:	learn: 0.1356149	total: 5.13s	remaining: 1.33s
# 397:	learn: 0.1354214	total: 5.14s	remaining: 1.32s
# 398:	learn: 0.1351860	total: 5.15s	remaining: 1.3s
# 399:	learn: 0.1350012	total: 5.17s	remaining: 1.29s
# 400:	learn: 0.1348045	total: 5.18s	remaining: 1.28s
# 401:	learn: 0.1345968	total: 5.19s	remaining: 1.26s
# 402:	learn: 0.1343819	total: 5.2s	remaining: 1.25s
# 403:	learn: 0.1342239	total: 5.21s	remaining: 1.24s
# 404:	learn: 0.1340053	total: 5.23s	remaining: 1.23s
# 405:	learn: 0.1338691	total: 5.24s	remaining: 1.21s
# 406:	learn: 0.1337055	total: 5.25s	remaining: 1.2s
# 407:	learn: 0.1335257	total: 5.26s	remaining: 1.19s
# 408:	learn: 0.1333953	total: 5.28s	remaining: 1.17s
# 409:	learn: 0.1331742	total: 5.29s	remaining: 1.16s
# 410:	learn: 0.1329845	total: 5.3s	remaining: 1.15s
# 411:	learn: 0.1327764	total: 5.32s	remaining: 1.14s
# 412:	learn: 0.1325239	total: 5.33s	remaining: 1.12s
# 413:	learn: 0.1323620	total: 5.34s	remaining: 1.11s
# 414:	learn: 0.1321543	total: 5.35s	remaining: 1.1s
# 415:	learn: 0.1319392	total: 5.37s	remaining: 1.08s
# 416:	learn: 0.1317063	total: 5.38s	remaining: 1.07s
# 417:	learn: 0.1314951	total: 5.39s	remaining: 1.06s
# 418:	learn: 0.1312269	total: 5.41s	remaining: 1.04s
# 419:	learn: 0.1309663	total: 5.42s	remaining: 1.03s
# 420:	learn: 0.1308548	total: 5.43s	remaining: 1.02s
# 421:	learn: 0.1305777	total: 5.44s	remaining: 1.01s
# 422:	learn: 0.1303129	total: 5.46s	remaining: 993ms
# 423:	learn: 0.1301242	total: 5.47s	remaining: 980ms
# 424:	learn: 0.1299461	total: 5.48s	remaining: 968ms
# 425:	learn: 0.1297636	total: 5.49s	remaining: 954ms
# 426:	learn: 0.1294734	total: 5.51s	remaining: 942ms
# 427:	learn: 0.1293498	total: 5.52s	remaining: 929ms
# 428:	learn: 0.1291344	total: 5.53s	remaining: 916ms
# 429:	learn: 0.1288894	total: 5.55s	remaining: 903ms
# 430:	learn: 0.1286608	total: 5.56s	remaining: 890ms
# 431:	learn: 0.1284913	total: 5.57s	remaining: 877ms
# 432:	learn: 0.1283790	total: 5.58s	remaining: 864ms
# 433:	learn: 0.1281667	total: 5.6s	remaining: 851ms
# 434:	learn: 0.1279359	total: 5.61s	remaining: 838ms
# 435:	learn: 0.1276158	total: 5.62s	remaining: 825ms
# 436:	learn: 0.1274035	total: 5.64s	remaining: 813ms
# 437:	learn: 0.1271678	total: 5.65s	remaining: 800ms
# 438:	learn: 0.1269558	total: 5.66s	remaining: 787ms
# 439:	learn: 0.1267687	total: 5.67s	remaining: 774ms
# 440:	learn: 0.1265582	total: 5.69s	remaining: 761ms
# 441:	learn: 0.1263334	total: 5.7s	remaining: 748ms
# 442:	learn: 0.1261189	total: 5.71s	remaining: 735ms
# 443:	learn: 0.1259126	total: 5.72s	remaining: 722ms
# 444:	learn: 0.1257879	total: 5.74s	remaining: 709ms
# 445:	learn: 0.1256353	total: 5.75s	remaining: 696ms
# 446:	learn: 0.1255265	total: 5.76s	remaining: 683ms
# 447:	learn: 0.1254280	total: 5.77s	remaining: 670ms
# 448:	learn: 0.1252736	total: 5.79s	remaining: 657ms
# 449:	learn: 0.1250749	total: 5.8s	remaining: 645ms
# 450:	learn: 0.1248272	total: 5.81s	remaining: 632ms
# 451:	learn: 0.1246009	total: 5.83s	remaining: 619ms
# 452:	learn: 0.1244700	total: 5.84s	remaining: 606ms
# 453:	learn: 0.1243043	total: 5.85s	remaining: 593ms
# 454:	learn: 0.1240985	total: 5.87s	remaining: 580ms
# 455:	learn: 0.1239524	total: 5.88s	remaining: 567ms
# 456:	learn: 0.1237428	total: 5.89s	remaining: 554ms
# 457:	learn: 0.1235743	total: 5.9s	remaining: 541ms
# 458:	learn: 0.1234306	total: 5.92s	remaining: 528ms
# 459:	learn: 0.1232729	total: 5.93s	remaining: 515ms
# 460:	learn: 0.1231569	total: 5.94s	remaining: 503ms
# 461:	learn: 0.1230549	total: 5.95s	remaining: 490ms
# 462:	learn: 0.1229464	total: 5.96s	remaining: 477ms
# 463:	learn: 0.1227231	total: 5.98s	remaining: 464ms
# 464:	learn: 0.1225589	total: 5.99s	remaining: 451ms
# 465:	learn: 0.1223693	total: 6s	remaining: 438ms
# 466:	learn: 0.1222728	total: 6.01s	remaining: 425ms
# 467:	learn: 0.1221153	total: 6.03s	remaining: 412ms
# 468:	learn: 0.1218865	total: 6.04s	remaining: 399ms
# 469:	learn: 0.1217139	total: 6.05s	remaining: 386ms
# 470:	learn: 0.1215593	total: 6.07s	remaining: 374ms
# 471:	learn: 0.1213389	total: 6.08s	remaining: 361ms
# 472:	learn: 0.1211514	total: 6.09s	remaining: 348ms
# 473:	learn: 0.1209360	total: 6.11s	remaining: 335ms
# 474:	learn: 0.1207243	total: 6.12s	remaining: 322ms
# 475:	learn: 0.1205186	total: 6.13s	remaining: 309ms
# 476:	learn: 0.1204070	total: 6.14s	remaining: 296ms
# 477:	learn: 0.1201901	total: 6.16s	remaining: 283ms
# 478:	learn: 0.1199766	total: 6.17s	remaining: 270ms
# 479:	learn: 0.1198030	total: 6.18s	remaining: 258ms
# 480:	learn: 0.1196387	total: 6.2s	remaining: 245ms
# 481:	learn: 0.1195251	total: 6.21s	remaining: 232ms
# 482:	learn: 0.1193781	total: 6.22s	remaining: 219ms
# 483:	learn: 0.1192777	total: 6.23s	remaining: 206ms
# 484:	learn: 0.1190674	total: 6.25s	remaining: 193ms
# 485:	learn: 0.1189765	total: 6.26s	remaining: 180ms
# 486:	learn: 0.1187883	total: 6.27s	remaining: 167ms
# 487:	learn: 0.1186304	total: 6.28s	remaining: 155ms
# 488:	learn: 0.1184750	total: 6.29s	remaining: 142ms
# 489:	learn: 0.1183169	total: 6.31s	remaining: 129ms
# 490:	learn: 0.1182162	total: 6.32s	remaining: 116ms
# 491:	learn: 0.1179731	total: 6.33s	remaining: 103ms
# 492:	learn: 0.1178906	total: 6.34s	remaining: 90.1ms
# 493:	learn: 0.1176785	total: 6.36s	remaining: 77.2ms
# 494:	learn: 0.1175033	total: 6.37s	remaining: 64.4ms
# 495:	learn: 0.1172946	total: 6.38s	remaining: 51.5ms
# 496:	learn: 0.1171214	total: 6.4s	remaining: 38.6ms
# 497:	learn: 0.1169686	total: 6.41s	remaining: 25.7ms
# 498:	learn: 0.1168044	total: 6.42s	remaining: 12.9ms
# 499:	learn: 0.1166276	total: 6.43s	remaining: 0us

# %% [markdown]
# ### 3b. Define explainer

# %%
# Define Anchor explainer
explainer = anchor_tabular.AnchorTabularExplainer(
    class_names=train_label.unique(),
    feature_names=train_set.columns,
    train_data=train_set.values
)

# %% [markdown]
# ### 4. Select the samples from the paper

# %%
# Filter out the same sample as in the paper
x1 = test_set[
    (test_set["education-num"] == 13) &     # Bachelors
    (test_set["occupation"] == 3) &         # Prof-speciality
    (test_set["sex"] == 0) &                # Male
    (test_set["native-country"] == 36) &    # Vietnam
    (test_set["age"] == 35) &               
    (test_set["workclass"] == 3) &
    (test_set["hours-per-week"] == 40) &
    (test_set["race"] == 3) &               # Asian-Pac-Islander
    (test_set["marital-status"] == 1) &     # Married-civ
    (test_set["relationship"] == 1) &       # Husband
    (test_set["capital-gain"] == 0) &
    (test_set["capital-loss"] == 0)
]
y1 = test_label.loc[x1.index]

print("Sample x1:\n", x1)
print('>50k?')
print("Label:", y1.item())
print("xgb:", xgb.predict(x1.values).item())
print("lg:", lg.predict(x1.values).item())
print("cat:", cat.predict(x1.values).item())


x2 = test_set[
    (test_set["education-num"] == 9) &     # College
    (test_set["occupation"] == 10) &         # Sales
    #(test_set["sex"] == 0) &                # Male
    #(test_set["native-country"] == 41) &    # US
    (test_set["age"] == 19) &               
    #(test_set["workclass"] == 2) &
    (test_set["hours-per-week"] == 15) &
    #(test_set["race"] == 1) &                 # White
    #(test_set["marital-status"] == 1) &     # Married-civ
    #(test_set["relationship"] == 1) &       # Husband
    (test_set["capital-gain"] == 0) &    
    (test_set["capital-loss"] == 0)
]
y2 = test_label.loc[x2.index]

print("Sample x1:\n", x2)
print('>50k?')
print("Label:", y2.item())
print("xgb:", xgb.predict(x1.values).item())
print("lg:", lg.predict(x1.values).item())
print("cat:", cat.predict(x1.values).item())
# Out:
# Sample x1:
#       age  workclass  fnlwgt  education-num  marital-status  occupation  \
# 166   35          3  110188             13               1           3
#
#      relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 166             1     3    0             0             0              40
#
#      native-country
# 166              36
# >50k?
# Label: 0
# xgb: 0
# lg: 0
# cat: 0
# Sample x1:
#        age  workclass  fnlwgt  education-num  marital-status  occupation  \
# 5609   19          2  119964              9               7          10
#
#       relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 5609             4     1    1             0             0              15
#
#       native-country
# 5609              41
# >50k?
# Label: 0
# xgb: 0
# lg: 0
# cat: 0

# %% [markdown]
# ### 5. Explain!

# %%
exp = explainer.explain_instance(
    data_row=x1.values,
    classifier_fn=xgb.predict,
    threshold=0.95
)

#exp.show_in_notebook()
print(exp.names())
print('Anchor explanation x1: %s' % (' AND '.join(exp.names())))
print('Precision: %.2f' % exp.precision())
print('Coverage: %.2f' % exp.coverage())


exp = explainer.explain_instance(
    data_row=x2.values,
    classifier_fn=xgb.predict,
    threshold=0.95
)

#exp.show_in_notebook()
print('Anchor explanation x2: %s' % (' AND '.join(exp.names())))
print('Precision: %.2f' % exp.precision())
print('Coverage: %.2f' % exp.coverage())
# Out:
# ['age <= 37.00', 'race > 1.00', 'hours-per-week <= 40.00', 'capital-gain <= 0.00', 'capital-loss <= 0.00', 'occupation <= 10.00', 'fnlwgt <= 179171.00']
# Anchor explanation x1: age <= 37.00 AND race > 1.00 AND hours-per-week <= 40.00 AND capital-gain <= 0.00 AND capital-loss <= 0.00 AND occupation <= 10.00 AND fnlwgt <= 179171.00
# Precision: 0.96
# Coverage: 0.02
# Anchor explanation x2: age <= 28.00 AND marital-status > 2.00
# Precision: 0.98
# Coverage: 0.20

# %% [markdown]
# ### 6a. Calculate Fidelity

# %%
import re
from tqdm import tqdm

def conv_rule_to_pandas_query(rule):
    """
    Converts Anchor rules (list of strings) into a valid pandas .query() expression.
    Supports compound range rules like '3.00 < occupation <= 5.00'.
    """
    query_parts = []
    
    for cond in rule:
        # Match compound ranges like '3.00 < occupation <= 5.00'
        match = re.match(r"([\d\.]+)\s*<\s*(.+)\s*<=\s*([\d\.]+)", cond)
        if match:
            low, col, high = match.groups()
            col = col.strip()
            expr = f"({float(low)} < `{col}` <= {float(high)})"
            query_parts.append(expr)
            continue
        
        # Match simple binary comparisons
        match = re.match(r"(.+?)\s*(<=|>=|<|>|==)\s*([\d\.]+)", cond)
        if match:
            col, op, val = match.groups()
            col = col.strip()
            expr = f"(`{col}` {op} {float(val)})"
            query_parts.append(expr)
            continue

        raise ValueError(f"Unsupported condition format: {cond}")
    
    return " & ".join(query_parts)

def calculate_fidelity(model, explainer, dataset, tresh=0.95, num_samples=100):
    fidelity_scores = []
    
    pbar = tqdm(range(num_samples), desc="Calculating fidelity")
    for i in pbar:
        # Get the instance and its true label
        x = dataset.iloc[i]
        y_true = model.predict(x.values.reshape(1, -1)).item()  # model prediction for the instance

        # Explain the instance with Anchor
        exp = explainer.explain_instance(x.values, classifier_fn=model.predict, threshold=tresh)
        rule = exp.names()  # e.g., ["age > 30", "capital-gain <= 0"]

        if not rule:
            pbar.set_postfix({"skipped": i})
            continue  # Skip if no rule found

        # Convert the Anchor rule to a pandas query expression
        query_str = conv_rule_to_pandas_query(rule)
        
        # Sample instances that satisfy the rule condition
        covered = dataset.query(query_str)
        
        # Check how many of the covered instances match the model's original prediction
        pred_match = model.predict(covered.values) == y_true
        fidelity = pred_match.mean() if len(covered) > 0 else 0
        
        fidelity_scores.append(fidelity)
        pbar.set_postfix({"current_fid": f"{fidelity:.2f}"})

    avg_fidelity = np.mean(fidelity_scores)
    print("Final fidelity:", avg_fidelity)
    return avg_fidelity

thresh = 0.4 # default: 0.95
fidelity_lg = calculate_fidelity(lg, explainer, test_set, tresh=thresh)
fidelity_xgb = calculate_fidelity(xgb, explainer, test_set, tresh=thresh)
fidelity_cat = calculate_fidelity(cat, explainer, test_set, tresh=thresh)
# Out:
# Calculating fidelity: 100%|██████████| 100/100 [00:24<00:00,  4.03it/s, skipped=99]
# Final fidelity: 0.8147183402477902
# Calculating fidelity: 100%|██████████| 100/100 [00:06<00:00, 14.70it/s, skipped=99]
# Final fidelity: 0.7841283062729928
# Calculating fidelity: 100%|██████████| 100/100 [00:19<00:00,  5.24it/s, current_fid=0.98]
# Final fidelity: 0.854246580338278

# %% [markdown]
# ### 6b. Calculate Faithfulness

# %% [markdown]
# ### 7. Calculate Stability

# %%
from tqdm import tqdm
from copy import deepcopy
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import MinMaxScaler

def jaccard_distance(exp_x: set, exp_x_neigh: set, debug):
    """Distance between two explanations."""
    union = exp_x | exp_x_neigh
    if not union:
        return 0.0  # If both are empty, treat as identical
    jacc = 1 - len(exp_x & exp_x_neigh) / len(union)
    if debug:
        print("\tJacc:\t", jacc)
    return jacc

def hamming_distance(exp_x: set, exp_x_neigh: set, debug=False):
    """Distance between two explanations using Hamming distance."""
    # Calculate the symmetric difference between the two sets
    diff = exp_x ^ exp_x_neigh  # ^ is symmetric difference
    # Normalize the distance by the maximum possible number of differences (size of the union)
    max_diff = max(len(exp_x), len(exp_x_neigh))
    if max_diff == 0:
        return 0.0  # If both are empty, treat as identical
    
    hamming = len(diff) / max_diff
    
    if debug:
        print("\tHamming:\t", hamming)
    
    return hamming

def eucl_distance(x1: np.ndarray, x2: np.ndarray, debug):
    """Euclidean distance between inputs."""
    eucl = np.linalg.norm(x1 - x2)
    if debug:
        print("\tEucl:\t", eucl)
    return eucl

def norm_eucl_distance(x1: np.ndarray, x2: np.ndarray, scaler: MinMaxScaler, debug):
    """Euclidean distance between inputs, first normalizing features."""
    
    # Normalize the input vectors (x1 and x2)
    x1_normalized = scaler.transform([x1])
    x2_normalized = scaler.transform([x2])

    # Calculate the Euclidean distance between the normalized vectors
    eucl_dist = np.linalg.norm(x1_normalized - x2_normalized)

    if debug:
        print("\tEuc_norm:\t", eucl_dist)
        
    return eucl_dist

def calc_lipschitz(exp_x, exp_xp, x, xp, debug, sim, scaler=None):
    if sim == "jaccard":
        exp_dist = jaccard_distance(exp_x, exp_xp, debug)
    else:
        exp_dist = hamming_distance(exp_x, exp_xp, debug)

    if scaler is not None:
        input_dist = norm_eucl_distance(x, xp, scaler, debug)
    else:
        input_dist = eucl_distance(x, xp, debug)

    lip = exp_dist/input_dist
    if debug:
        print("\tLip:\t", lip)
    return lip

def generate_perturbation_neighborhood(x: pd.Series, dataset: pd.DataFrame, num_samples=10, max_perturbation=2):
    """Generates a synthetic neighborhood around x by applying small perturbations."""
    neighborhood = []

    for _ in range(num_samples):
        x_prime = deepcopy(x)

        for col in dataset.columns:
            # Apply a small perturbation, limiting to max_perturbation in magnitude
            perturbation = np.random.randint(-max_perturbation, max_perturbation + 1)
            new_value = x[col] + perturbation

            # Ensure the perturbed value is non-negative (not below 0)
            x_prime[col] = max(0, new_value)

        neighborhood.append(x_prime.values)

    return np.array(neighborhood)

def sample_neighborhood(x: np.ndarray, nn: NearestNeighbors, dataset: pd.DataFrame, k=10):
    _, indices = nn.kneighbors(x, n_neighbors=k)
    neigh_idcs = indices[0][1:]
    neigh_vals = dataset.iloc[neigh_idcs].values
    return neigh_vals


def calculate_stability(model, explainer, dataset, k_neighbors=10, thresh=0.95, num_samples=1, debug=False, neigh="gen", sim="jaccard", norm=False):
    assert neigh in ["gen","sampled"]
    assert sim in ["jaccard","hamming"]

    stability_scores = []
    if neigh == "sampled":
        nn = NearestNeighbors(n_neighbors=k_neighbors + 1).fit(dataset.values)

    if norm:
        scaler = MinMaxScaler()
        scaler.fit_transform(dataset.values)

    for i in tqdm(range(num_samples), desc="Calculating stability..."):
        x = dataset.iloc[i]
        x_val = x.values.reshape(1, -1)
        if debug:
            print("Row:\t", list(x.values))

        try:
            anchor_x = explainer.explain_instance(x_val[0], classifier_fn=model.predict, threshold=thresh)
            rule_x = set(anchor_x.names())
            if not rule_x:
                if debug:
                    print(f"No rule on index {i}. Skipping instance...")
                continue  # Skip if no rule was found
            if debug:
                print("Exp:\t", anchor_x.names())
        except:
            if debug:
                print(f"Anchor failed on index {i}. Skipping instance...")
            continue  # Skip instances where anchor fails

        # Find neighbors (excluding self)
        if neigh == "gen":
            neigh_vals = generate_perturbation_neighborhood(x, dataset, num_samples=k_neighbors)
        else:
            neigh_vals = sample_neighborhood(x_val, nn, dataset)

        lipschitz_vals = []
        for j, x_prime in enumerate(neigh_vals):
            if debug:
                print(f"\n\tNN{j}:\t", list(x_prime))
            #try:
            anchor_xp = explainer.explain_instance(x_prime.reshape(1, -1), classifier_fn=model.predict, threshold=thresh)
            if debug:
                print("\tExp:\t", anchor_xp.names())
            
            rule_xp = set(anchor_xp.names())

            lip = calc_lipschitz(
                exp_x=rule_x,
                exp_xp=rule_xp,
                x=x.values,
                xp=x_prime,
                debug=debug,
                sim=sim,
                scaler=scaler if norm else None
            )
            lipschitz_vals.append(lip)
            #except:
                #print(f"Error occured in neighbor explanation. Skipping instance.")
                #continue  # If explanation fails, skip

        if lipschitz_vals:
            max_lip = np.max(lipschitz_vals)
            if debug:
                print("\nMax Lipstein:\t", max_lip)
            stability_scores.append(max_lip)

    return np.mean(stability_scores) if stability_scores else 0.0

num_samples = 5
debug = False
neigh = "sampled" # "gen" | "sampled"
sim = "hamming" # "hamming" | "jaccard"
norm = True

stabilities = []
for model in [lg, xgb, cat]:
    stability = calculate_stability(
        xgb, explainer, test_set, 
        num_samples=num_samples,
        debug=debug,
        neigh=neigh,
        sim=sim,
        norm=norm
    )
    stabilities.append(stability)

print("LG Stability:", stabilities[0])
print("XGB Stability:", stabilities[1])
print("CAT Stability:", stabilities[2])
# Out:
# Calculating stability...: 100%|██████████| 5/5 [00:33<00:00,  6.74s/it]
# Calculating stability...: 100%|██████████| 5/5 [00:32<00:00,  6.42s/it]
# Calculating stability...: 100%|██████████| 5/5 [00:34<00:00,  6.92s/it]
# LG Stability: 2.4909891679452683
# XGB Stability: 2.618334095670109
# CAT Stability: 2.7905672606973715
